# %% [markdown]
# <div style = "background-color:lightblue; color:green">Exploratory Data Analysis(EDA) is the process of understanding the dataset before applying it for models<br>
# or making any decision.<br>
# It is mainly concerned with converting raw data into useful data by looking into the data, handaling missing values, detecting outliers and observing patterns/characteristics.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

from pandas import Series
from pandas import DataFrame

# %%
data = pd.read_csv('/home/kartika/Datasets/Customer Churn.csv')
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data[data['TotalCharges'] == ' ']
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines InternetService       OnlineSecurity         OnlineBackup     DeviceProtection          TechSupport          StreamingTV      StreamingMovies  Contract PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   4472-LVYGI  Female              0     Yes        Yes       0           No  No phone service             DSL                  Yes                   No                  Yes                  Yes                  Yes                   No  Two year              Yes  Bank transfer (automatic)           52.55                 No
# 753   3115-CZMZD    Male              0      No        Yes       0          Yes                No              No  No internet service  No internet service  No internet service  No internet service  No internet service  No internet service  Two year               No               Mailed check           20.25                 No
# ...

# %%
data['TotalCharges'] = data['TotalCharges'].replace(" ",0)
data['TotalCharges'] = data['TotalCharges'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# <div style = "color:blue; font-size:20px">Since, tenure is 0, no charges is recorded in total charges. So we repalced blank with 0 as dtype float.

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# <div style = "color:blue; font-size:20px">There is no null/missing values throughout the dataframe.

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <div style = "color:blue; font-size:20px">No duplicate data throughout the dataframe.

# %%
data['SeniorCitizen'] = data['SeniorCitizen'].replace({0:'No',1:'Yes'})
#data['SeniorCitizen'] = data['SeniorCitizen'].map({0:'No',1:'Yes'})     Using Function Mappling

# def conv(x):
#     if x == 0:
#         return 'No'
#     else:
#         return 'Yes'
# data['SeniorCitizen'] = data['SeniorCitizen'].apply(conv)     Using Function Application

# %%
data.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0  7590-VHVEG  Female            No     Yes         No       1           No  No phone service             DSL             No          Yes               No          No          No              No  Month-to-month              Yes           Electronic check           29.85         29.85    No
# 1  5575-GNVDE    Male            No      No         No      34          Yes                No             DSL            Yes           No              Yes          No          No              No        One year               No               Mailed check           56.95       1889.50    No
# ...

# %% [markdown]
# <div style = "color:blue; font-size:20px">In the column SeniorCitizen 0 represents No and 1 represents Yes. This format is not suitable for all users
# ,so we converted 0 to No and 1 to Yes.

# %%
ax = sns.countplot(x = 'Churn', data = data)
ax.bar_label(ax.containers[0])
plt.figure(figsize=(10,6))
plt.show()

# %%
plt.figure(figsize = (3,4))

gb = data.groupby('Churn').agg({'Churn':'count'})

plt.pie(gb['Churn'], labels = gb.index, autopct = '%1.2f%%')
plt.title("Percentage of Customers by Churn")
plt.show()


# g = data['Churn'].groupby(data['Churn']).count()
# print(g)
# plt.pie(g, labels = g.index, autopct = '%1.2f%%')
# plt.show()
#Grouping in Series

# %% [markdown]
# <div style = "color:blue; font-size:20px">From the above graph, we can conclude that 26.54% of the customers have churned out.

# %%
plt.figure(figsize=(5,4))
sns.countplot(x = 'gender', data = data, hue = 'Churn')
plt.title("Churn by Gender")
plt.show()

# %% [markdown]
# <div style = "color:blue; font-size:20px">From the above graph, the number of churn in both male and female is almost same. Hence, churn is independent to gender.

# %%
# Calculate counts
gb = data.groupby(['SeniorCitizen', 'Churn']).size().unstack()

# Calculate percentages
gb_pct = gb.div(gb.sum(axis=1), axis=0) * 100

# Plot stacked bar chart
ax = gb_pct.plot(kind='bar', stacked=True, figsize=(5,4))
plt.title("Churn by Senior Citizen Status (Percentage)")
plt.ylabel("Percentage (%)")

# Add percentage labels on bars
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    ax.text(x + width / 2, y + height / 2, f'{height:.1f}%', ha='center', va='center')

plt.show()

# %%
ax = sns.histplot(x='SeniorCitizen', data = data, hue = 'Churn')
ax.bar_label(ax.containers[0])
plt.title("Churn by Senior Citizen Status")
plt.show()

# %% [markdown]
# <div style = "color:blue; font-size:20px">From the above graph, comparatively the percentage of churn in senior citizen is more.

# %%
sns.histplot(x='tenure', data = data, edgecolor = 'lightblue',bins = 70, hue = 'Churn')

plt.figure(figsize=(20,5))
plt.show()

# %% [markdown]
# <div style = "color:blue; font-size:20px">From the above graph, we can see most of the people have chured in the first two months.

# %% [markdown]
# <div></div>

# %%
ax = sns.countplot(x = 'Contract', data = data, hue = 'Churn')
ax.bar_label(ax.containers[0])
plt.title('Count of Customers by contract')
plt.show()

# %% [markdown]
# <div style = "color:blue; font-size:20px">From the above graph, we can conclude, there is greater churn for month-to-month contract. <br>
# So, churn can be decreased by making customers go for one or two year plan.

# %% [markdown]
# <div></div>

# %% [markdown]
# <div></div>
